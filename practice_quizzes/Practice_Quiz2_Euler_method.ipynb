# %% [markdown]
# # Practice Coding Quiz 2: The Euler Method
# *written by Rose Finn*
#
#
# # Directions
#
# * Please complete the Questions below - You can not use any resources except your brain!
# * Make sure to add comment strings for the function you write.
# * Be sure to comment your code so I can understand what you are thinking and give partial credit if needed.
# * Use descriptive variable names.
#
# # Submitting Your Notebook
#
# * Be sure to click the submit link!!!

# %%
# import numpy and pyplot here

# %% [markdown]
# ## Part 1
#
# Write a function `initialize` to create arrays to store the values of time, position, and velocity.
#
# * Input Parameters
#   * nsteps
#   * initial position, **y0**
#   * initial velocity, **v0y**
#
# * The function should
#   * define an array for time, position, and velocity using `np.zeros(nsteps)`
#   * set the first element of the position array to **y0**
#   * set the first element of the velocity array to **v0y**
#
# * Return:
#   * time array
#   * position array
#   * velocity array

# %%
# your initialize function here

# %% [markdown]
# ## Part 2
#
# Please write a function, `calculate`, that calculates the Euler method for a ball that is falling vertically (1D motion) WITHOUT air resistance.  This means that the acceleration is just the acceleration of gravity.
#
# * Input parameters:
#   * time array, **time**
#   * position array, **ypos**
#   * velocity array, **yvel**
#   * time step dt
#
# * The function should loop from 1 to the length of the position array, and calculate the time, position, and velocity at each step.
#
# * Return:
#   * time array
#   * position array
#   * velocity array

# %%
# write your calculate function here

def calculate(time,ypos,yvel,dt):

  a = -9.8

  # add your loop to calculate the Euler method



  return time, ypos, yvel

# %% [markdown]
# ## Part 3
#
# Use your functions from `Part 1` and `Part 2` to:
# * determine the y position and velocity as a function of time.
# * plot position versus time
# * plot velocity versus time
#
#
# **Bonus** Use `plt.suplot` command to plot your position and velocity graphs next to each other in the same figure.

# %%
# set up initial conditions
y0 = 0 # initial y position
v0y = 20 # m/s
nsteps = 23
dt = 0.2# 0.2 seconds

# call initialize


# call calculate

# plot position versus time
plt.figure()


# plot velocity versus time
